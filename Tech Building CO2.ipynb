# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as py

# %%
df = pd.read_csv('COb.csv')

# %%
df
# Out:
#      CO2(ppm)   TVOC   temperature
# 0        1153    114     25.000000
# 1         409      1     25.502293
# 2         433      5     25.000000
# 3         436      5     25.885364
# 4         436      5     24.114636
# 5         400      0     25.502293
# 6         405      0     24.616929
# 7         444      6     25.502293
# 8         459      8     25.000000
# 9         459      8     25.502293
# 10        481     12     24.616929
# 11        493     14     25.885364
# 12        594     29     24.616929
# 13        600     30     25.885364
# 14        615     32     25.000000
# 15        615     32     25.885364
# 16        588     28     25.000000
# 17        594     29     25.885364
# 18        594     29     25.000000
# 19        674     41     25.885364
# 20        629     34     24.616929
# 21        623     33     25.502293
# 22        637     36     25.000000
# 23        637     36     25.885364
# 24        629     34     25.000000
# 25        650     38     25.885364
# ...
